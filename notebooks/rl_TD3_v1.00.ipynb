# %%
import numpy as np
import torch
import gym
import os
from agent import TD3
from util import ReplayBuffer

# %%
policy_name = "TD3"
env_name = "BipedalWalker-v2"
seed = 0
filename = f"{policy_name}-{env_name}-{str(seed)}"
start_timesteps = 1e4
eval_freq = 5e3
max_timesteps = 1e6
save_models = True
expl_noise = 0.1
batch_size = 100
discount = 0.99
tau = 0.005
policy_noise = 0.2
noise_clip = 0.5
policy_freq = 2

# print(filename)

if not os.path.exists("./results"):
    os.makedirs("./results")
if save_models and not os.path.exists("./pytorch_models"):
    os.makedirs("./pytorch_models")
# Out:
# TD3-BipedalWalker-v2-0

# %%
def evaluate_policy(policy, eval_episodes=10):
    avg_reward = 0.
    for _ in range(eval_episodes):
        obs = env.reset()
        done = False
        while not done:
            action = policy.select_action(np.array(obs))
            obs, reward, done, _ = env.step(action)
            avg_reward += reward
            
    avg_reward /= eval_episodes
    print(f"Evaluation over {eval_episodes} episodes: {avg_reward}")
    return avg_reward

# %%
env = gym.make(env_name)
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

policy = TD3(state_dim, action_dim, max_action)

replay_buffer = ReplayBuffer()

evaluations = [evaluate_policy(policy)]

total_timesteps = 0
timesteps_since_eval = 0
episode_num = 0
done = True

while total_timesteps < max_timesteps:
    if done:
        if total_timesteps !=0:
            print(f"Total T: {total_timesteps} Episode Num: {episode_num} Episode T: {episode_timesteps} Reward: {episode_reward}")
            policy.train(replay_buffer, episode_timesteps, batch_size, discount, tau, policy_noise, noise_clip, policy_freq)
        if timesteps_since_eval > eval_freq:
            timesteps_since_eval %= eval_freq
            evaluations.append(evaluate_policy(policy))
            
            if save_models: policy.save(filename, directory="./pytorch_models")
            np.save(f"./results/{filename}",evaluations)
            
        obs = env.reset()
        done = False
        episode_reward = 0
        episode_timesteps = 0
        episode_num +=1
        
        
    if total_timesteps < start_timesteps:
        action = env.action_space.sample()
    else:
        action = policy.select_action(np.array(obs))
        if expl_noise != 0:
            action = (action + np.random.normal(0, expl_noise, size=env.action_space.shape[0])).clip(env.action_space.low, env.action_space.high)
    
    new_obs, reward, done, _ = env.step(action)
    done_bool = 0 if episode_timesteps + 1 == env._max_episode_steps else float(done)
    episode_reward += reward
    
    replay_buffer.add((obs, new_obs, action, reward, done_bool))
    obs = new_obs
    
    episode_timesteps += 1
    total_timesteps += 1
    timesteps_since_eval += 1

evaluations.append(evaluate_policy(policy))
if save_models: policy.save(f"{filename}",directory="./pytorch_models")
np.save(f"./results/{filename}",evaluations)
# Out:
# Evaluation over 10 episodes: -118.46731245457529
# Total T: 64 Episode Num: 1 Episode T: 64 Reward: -100.18085529850983
# Total T: 1664 Episode Num: 2 Episode T: 1600 Reward: -82.02193539054794
# Total T: 3264 Episode Num: 3 Episode T: 1600 Reward: -79.50127513945797
# Total T: 4864 Episode Num: 4 Episode T: 1600 Reward: -82.10784610391238
# Total T: 4985 Episode Num: 5 Episode T: 121 Reward: -101.48584581220507
# Total T: 6585 Episode Num: 6 Episode T: 1600 Reward: -90.7804433609247
# Evaluation over 10 episodes: -23.646632089354284
# Total T: 8185 Episode Num: 7 Episode T: 1600 Reward: -83.27493059260918
# Total T: 143307 Episode Num: 160 Episode T: 1600 Reward: -43.784352923383246
# Total T: 144907 Episode Num: 161 Episode T: 1600 Reward: -56.59951801774023
# Total T: 146507 Episode Num: 162 Episode T: 1600 Reward: -71.84554470783226
# Evaluation over 10 episodes: -45.134561423285085
# Total T: 148107 Episode Num: 163 Episode T: 1600 Reward: -61.20685097355782
# Total T: 149707 Episode Num: 164 Episode T: 1600 Reward: -83.97949723199343
# Total T: 151307 Episode Num: 165 Episode T: 1600 Reward: -37.864573907806815
# Evaluation over 10 episodes: -69.80219140850899
# Total T: 152907 Episode Num: 166 Episode T: 1600 Reward: -66.56197654932174
# Total T: 154507 Episode Num: 167 Episode T: 1600 Reward: -46.23689939213997
# Total T: 156107 Episode Num: 168 Episode T: 1600 Reward: -68.6818759490354
# Evaluation over 10 episodes: -19.6655274280156
# Total T: 157707 Episode Num: 169 Episode T: 1600 Reward: -35.30713472288876
# Total T: 159307 Episode Num: 170 Episode T: 1600 Reward: -42.90081668596138
# Total T: 160907 Episode Num: 171 Episode T: 1600 Reward: -52.12473875100045
# Evaluation over 10 episodes: -28.343463844102075
# Total T: 162507 Episode Num: 172 Episode T: 1600 Reward: -31.121662592549697
# Total T: 164107 Episode Num: 173 Episode T: 1600 Reward: -39.4465627690218
# Total T: 165707 Episode Num: 174 Episode T: 1600 Reward: -42.057471544033106
# Evaluation over 10 episodes: -36.248853204487354
# Total T: 167307 Episode Num: 175 Episode T: 1600 Reward: -38.647628542167496
# Total T: 168907 Episode Num: 176 Episode T: 1600 Reward: -40.51627573640874
# Total T: 170507 Episode Num: 177 Episode T: 1600 Reward: -20.022050164473175
# Evaluation over 10 episodes: -72.07612741818421
# Total T: 172107 Episode Num: 178 Episode T: 1600 Reward: -68.45912590895166
# Total T: 173707 Episode Num: 179 Episode T: 1600 Reward: -28.88574749787973
# Total T: 175307 Episode Num: 180 Episode T: 1600 Reward: -32.794079194885
# Evaluation over 10 episodes: -20.91632169063815
# Total T: 176907 Episode Num: 181 Episode T: 1600 Reward: -28.034651695194913
# Total T: 178507 Episode Num: 182 Episode T: 1600 Reward: -31.669831854473955
# Total T: 178571 Episode Num: 183 Episode T: 64 Reward: -118.36081152396659
# Total T: 180171 Episode Num: 184 Episode T: 1600 Reward: -30.735598692273083
# Evaluation over 10 episodes: -31.01593107343159
# Total T: 181771 Episode Num: 185 Episode T: 1600 Reward: -58.42039953012651
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-deaa4b20ce74> in <module>
#      23         if total_timesteps !=0:
#      24             print(f"Total T: {total_timesteps} Episode Num: {episode_num} Episode T: {episode_timesteps} Reward: {episode_reward}")
# ---> 25             policy.train(replay_buffer, episode_timesteps, batch_size, discount, tau, policy_noise, noise_clip, policy_freq)
#      26         if timesteps_since_eval > eval_freq:
#      27             timesteps_since_eval %= eval_freq
#
# /Volumes/BC_Clutch/Dropbox/Programming/Classes/Udacity/DeepRLND/rl_continuous_control/notebooks/TD3.py in train(self, replay_buffer, iterations, batch_size, discount, tau, policy_noise, noise_clip, policy_freq)
#
# ~/anaconda3/envs/drlnd2/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#     104                 step_size = group['lr'] * math.sqrt(bias_correction2) / bias_correction1
#     105
# --> 106                 p.data.addcdiv_(-step_size, exp_avg, denom)
#     107
#     108         return loss
#
# KeyboardInterrupt:
